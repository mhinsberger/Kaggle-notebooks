# %% [markdown]
# <a href="https://www.kaggle.com/code/mariushinsberger/titanic-first-approaches?scriptVersionId=160495362" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %% [markdown]
# # Imports

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Load Data

# %%
path = str("/kaggle/input/titanic")
train_data = pd.read_csv(f"{path}/train.csv")
test_data = pd.read_csv(f"{path}/test.csv")
submission_data = pd.read_csv(f"{path}/gender_submission.csv")

# %% [markdown]
# # Process data

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train_data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_data.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
def clean_data(train, test):
    for df in [train, test]:    
        # Rename columns.
        df.rename(columns={"PassengerId": "passenger_id", "Survived": "survived", "Pclass": "p_class", "Name": "name", "Sex": "sex", "Age": "age", "SibSp": "sib_sp",
           "Parch": "parch", "Ticket": "ticket", "Fare": "fare", "Cabin": "cabin", "Embarked": "embarked"}, inplace=True)
        # Drop unneeded columns.
        df.drop(columns=["name", "ticket", "cabin", "passenger_id"], inplace=True)
        # Add feature median to missing categorical values.
        df["embarked"] = df["embarked"].astype(str)
    
    embarked_mode = train["embarked"].mode()
    age_median = train["age"].median()
    fare_median = train["fare"].median()
    
    for df in [train, test]:
        df["embarked"].fillna(embarked_mode, inplace=True)
        df["age"].fillna(age_median, inplace=True)
        df["fare"].fillna(fare_median, inplace=True)
        # Change datatype of numerical values to integer.
        df["age"] = df["age"].astype(int)
        df["parch"] = df["parch"].astype(int)
        df["fare"] = df["fare"].astype(int)
    
    # Transform categorical values.
    train["p_class"] = le.fit_transform(train["p_class"].values)
    test["p_class"] = le.transform(test["p_class"].values)
    
    train["sex"] = le.fit_transform(train["sex"].values)
    test["sex"] = le.transform(test["sex"].values)
    
    train["sib_sp"] = le.fit_transform(train["sib_sp"].values)
    test["sib_sp"] = le.transform(test["sib_sp"].values)
    
    #train["parch"] = le.fit_transform(train["parch"].values)
    #test["parch"] = le.transform(test["parch"].values)
    
    train["embarked"] = le.fit_transform(train["embarked"].values)
    test["embarked"] = le.transform(test["embarked"].values)
    
    #train["fare"] = le.fit_transform(train["fare"].values)
    #test["fare"] = le.transform(test["fare"].values)
    

    # return clean dataframe.
    return train, test

# %%
le = LabelEncoder()
train_df, test_df = clean_data(train_data, test_data)

# %%
train_data.isna().sum()
# Out:
# survived    0
# p_class     0
# sex         0
# age         0
# sib_sp      0
# parch       0
# fare        0
# embarked    0
# dtype: int64

# %%
test_data.isna().sum()
# Out:
# p_class     0
# sex         0
# age         0
# sib_sp      0
# parch       0
# fare        0
# embarked    0
# dtype: int64

# %%
train_data.head()
# Out:
#    survived  p_class  sex  age  sib_sp  parch  fare  embarked
# 0         0        2    1   22       1      0     7         2
# 1         1        0    0   38       1      0    71         0
# 2         1        2    0   26       0      0     7         2
# 3         1        0    0   35       1      0    53         2
# 4         0        2    1   35       0      0     8         2

# %%
train_df.corrwith(train_df["survived"]).abs().sort_values(ascending=False)
# Out:
# survived    1.000000
# sex         0.543351
# p_class     0.338481
# fare        0.257482
# embarked    0.163517
# parch       0.081629
# age         0.064909
# sib_sp      0.026385
# dtype: float64

# %% [markdown]
# # Build model

# %%
X_train = train_df.drop(columns=["survived"])
y_train = train_df["survived"]
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
xgb1 = XGBClassifier(
    learning_rate =0.1,
    n_estimators=1000,
    early_stopping_rounds=50,
    max_depth=6,
    min_child_weight=0,
    gamma=0.45,
    subsample=1.0,
    colsample_bytree=0.75,
    objective= 'binary:logistic',
    nthread=-1,
    scale_pos_weight=1,
    random_state=42
)
xgb1.fit(X_train, y_train, eval_set=[(X_val, y_val)])
acc_train = accuracy_score(xgb1.predict(X_train),y_train)
acc_val = accuracy_score(xgb1.predict(X_val),y_val)
print(f"model: xgb1\ntrain_accuracy: {acc_train:.4f}\ntest_accuracy: {acc_val:.4f}")
# Out:
# [0]	validation_0-logloss:0.63546
# [1]	validation_0-logloss:0.60291
# [2]	validation_0-logloss:0.57471
# [3]	validation_0-logloss:0.56168
# [4]	validation_0-logloss:0.54778
# [5]	validation_0-logloss:0.53945
# [6]	validation_0-logloss:0.52324
# [7]	validation_0-logloss:0.51639
# [8]	validation_0-logloss:0.50837
# [9]	validation_0-logloss:0.50170
# [10]	validation_0-logloss:0.49576
# [11]	validation_0-logloss:0.48527
# [12]	validation_0-logloss:0.47432
# [13]	validation_0-logloss:0.46391
# [14]	validation_0-logloss:0.46045
# [15]	validation_0-logloss:0.45786
# [16]	validation_0-logloss:0.44506
# [17]	validation_0-logloss:0.43957
# [18]	validation_0-logloss:0.43780
# [19]	validation_0-logloss:0.43389
# [20]	validation_0-logloss:0.43026
# [21]	validation_0-logloss:0.42633
# [22]	validation_0-logloss:0.42346
# [23]	validation_0-logloss:0.42073
# [24]	validation_0-logloss:0.41784
# [25]	validation_0-logloss:0.41639
# [26]	validation_0-logloss:0.41459
# [27]	validation_0-logloss:0.41182
# [28]	validation_0-logloss:0.41042
# [29]	validation_0-logloss:0.40674
# [30]	validation_0-logloss:0.40717
# [31]	validation_0-logloss:0.40665
# [32]	validation_0-logloss:0.40391
# [33]	validation_0-logloss:0.40331
# [34]	validation_0-logloss:0.40301
# [35]	validation_0-logloss:0.40229
# [36]	validation_0-logloss:0.40236
# [37]	validation_0-logloss:0.40264
# [38]	validation_0-logloss:0.40241
# [39]	validation_0-logloss:0.40234
# [40]	validation_0-logloss:0.40315
# [41]	validation_0-logloss:0.40241
# [42]	validation_0-logloss:0.40250
# [43]	validation_0-logloss:0.40250
# [44]	validation_0-logloss:0.40259
# [45]	validation_0-logloss:0.40248
# [46]	validation_0-logloss:0.40296
# [47]	validation_0-logloss:0.40215
# [48]	validation_0-logloss:0.40215
# [49]	validation_0-logloss:0.40215
# [50]	validation_0-logloss:0.40216
# [51]	validation_0-logloss:0.40216
# [52]	validation_0-logloss:0.40216
# [53]	validation_0-logloss:0.40216
# [54]	validation_0-logloss:0.40216
# [55]	validation_0-logloss:0.40216
# [56]	validation_0-logloss:0.40216
# [57]	validation_0-logloss:0.40216
# [58]	validation_0-logloss:0.40216
# [59]	validation_0-logloss:0.40216
# [60]	validation_0-logloss:0.40216
# [61]	validation_0-logloss:0.40217
# [62]	validation_0-logloss:0.40217
# [63]	validation_0-logloss:0.40217
# [64]	validation_0-logloss:0.40217
# [65]	validation_0-logloss:0.40217
# [66]	validation_0-logloss:0.40217
# [67]	validation_0-logloss:0.40217
# [68]	validation_0-logloss:0.40217
# [69]	validation_0-logloss:0.40217
# [70]	validation_0-logloss:0.40217
# [71]	validation_0-logloss:0.40217
# [72]	validation_0-logloss:0.40217
# [73]	validation_0-logloss:0.40217
# [74]	validation_0-logloss:0.40217
# [75]	validation_0-logloss:0.40217
# [76]	validation_0-logloss:0.40217
# [77]	validation_0-logloss:0.40217
# [78]	validation_0-logloss:0.40217
# [79]	validation_0-logloss:0.40217
# [80]	validation_0-logloss:0.40217
# [81]	validation_0-logloss:0.40217
# [82]	validation_0-logloss:0.40217
# [83]	validation_0-logloss:0.40217
# [84]	validation_0-logloss:0.40217
# [85]	validation_0-logloss:0.40217
# [86]	validation_0-logloss:0.40217
# [87]	validation_0-logloss:0.40217
# [88]	validation_0-logloss:0.40217
# [89]	validation_0-logloss:0.40217
# [90]	validation_0-logloss:0.40217
# [91]	validation_0-logloss:0.40217
# [92]	validation_0-logloss:0.40217
# [93]	validation_0-logloss:0.40217
# [94]	validation_0-logloss:0.40217
# [95]	validation_0-logloss:0.40217
# [96]	validation_0-logloss:0.40217
# model: xgb1
# train_accuracy: 0.8961
# test_accuracy: 0.8156

# %%
param_grid = {
    #"max_depth": [3,4,5,6,7,8,9],
    #"min_child_weight": [0,1,2],
    #"gamma": [0.35, 0.4, 0.45],
    #"subsample": [0.95, 1.0],
    #"colsample_bytree": [0.75, 0.8, 0.85],
    #"reg_alpha":[1e-5,1e-4,1e-6]
}
gs = GridSearchCV(
    estimator=XGBClassifier(
        learning_rate =0.1,
        n_estimators=97,
        early_stopping_rounds=50,
        max_depth=6,
        min_child_weight=0,
        gamma=0.45,
        subsample=1.0,
        colsample_bytree=0.75,
        objective= 'binary:logistic',
        nthread=-1,
        scale_pos_weight=1,
        random_state=42
    ),
    param_grid = param_grid, 
    scoring='roc_auc',
    n_jobs=4, 
    cv=5
)
#gs.fit(X_train, y_train, eval_set=[(X_val, y_val)])
#acc_train = accuracy_score(gs.predict(X_train),y_train)
#acc_val = accuracy_score(gs.predict(X_val),y_val)
#print(f"model: xgb1\ntrain_accuracy: {acc_train:.4f}\ntest_accuracy: {acc_val:.4f}")
#print(f"Best params: {gs.best_params_}\n Best score: {gs.best_score_}")

# %%
xgb2 =XGBClassifier(
    learning_rate =0.1,
    n_estimators=1000,
    early_stopping_rounds=50,
    max_depth=6,
    min_child_weight=0,
    gamma=0.45,
    subsample=1.0,
    colsample_bytree=0.75,
    reg_alpha=1e-5,
    objective= 'binary:logistic',
    nthread=-1,
    scale_pos_weight=1,
    random_state=42
)
xgb2.fit(X_train, y_train, eval_set=[(X_val, y_val)])
acc_train = accuracy_score(xgb2.predict(X_train),y_train)
acc_val = accuracy_score(xgb2.predict(X_val),y_val)
print(f"model: xgb1\ntrain_accuracy: {acc_train:.4f}\ntest_accuracy: {acc_val:.4f}")
# Out:
# [0]	validation_0-logloss:0.63546
# [1]	validation_0-logloss:0.60291
# [2]	validation_0-logloss:0.57471
# [3]	validation_0-logloss:0.56168
# [4]	validation_0-logloss:0.54778
# [5]	validation_0-logloss:0.53945
# [6]	validation_0-logloss:0.52324
# [7]	validation_0-logloss:0.51639
# [8]	validation_0-logloss:0.50837
# [9]	validation_0-logloss:0.50170
# [10]	validation_0-logloss:0.49576
# [11]	validation_0-logloss:0.48527
# [12]	validation_0-logloss:0.47432
# [13]	validation_0-logloss:0.46391
# [14]	validation_0-logloss:0.46045
# [15]	validation_0-logloss:0.45786
# [16]	validation_0-logloss:0.44506
# [17]	validation_0-logloss:0.43957
# [18]	validation_0-logloss:0.43780
# [19]	validation_0-logloss:0.43389
# [20]	validation_0-logloss:0.43026
# [21]	validation_0-logloss:0.42633
# [22]	validation_0-logloss:0.42346
# [23]	validation_0-logloss:0.42073
# [24]	validation_0-logloss:0.41784
# [25]	validation_0-logloss:0.41639
# [26]	validation_0-logloss:0.41459
# [27]	validation_0-logloss:0.41182
# [28]	validation_0-logloss:0.41042
# [29]	validation_0-logloss:0.40674
# [30]	validation_0-logloss:0.40717
# [31]	validation_0-logloss:0.40665
# [32]	validation_0-logloss:0.40391
# [33]	validation_0-logloss:0.40331
# [34]	validation_0-logloss:0.40301
# [35]	validation_0-logloss:0.40229
# [36]	validation_0-logloss:0.40236
# [37]	validation_0-logloss:0.40264
# [38]	validation_0-logloss:0.40241
# [39]	validation_0-logloss:0.40234
# [40]	validation_0-logloss:0.40315
# [41]	validation_0-logloss:0.40241
# [42]	validation_0-logloss:0.40250
# [43]	validation_0-logloss:0.40250
# [44]	validation_0-logloss:0.40259
# [45]	validation_0-logloss:0.40248
# [46]	validation_0-logloss:0.40296
# [47]	validation_0-logloss:0.40215
# [48]	validation_0-logloss:0.40215
# [49]	validation_0-logloss:0.40215
# [50]	validation_0-logloss:0.40216
# [51]	validation_0-logloss:0.40216
# [52]	validation_0-logloss:0.40216
# [53]	validation_0-logloss:0.40216
# [54]	validation_0-logloss:0.40216
# [55]	validation_0-logloss:0.40216
# [56]	validation_0-logloss:0.40216
# [57]	validation_0-logloss:0.40216
# [58]	validation_0-logloss:0.40216
# [59]	validation_0-logloss:0.40216
# [60]	validation_0-logloss:0.40217
# [61]	validation_0-logloss:0.40217
# [62]	validation_0-logloss:0.40217
# [63]	validation_0-logloss:0.40217
# [64]	validation_0-logloss:0.40217
# [65]	validation_0-logloss:0.40217
# [66]	validation_0-logloss:0.40217
# [67]	validation_0-logloss:0.40217
# [68]	validation_0-logloss:0.40217
# [69]	validation_0-logloss:0.40217
# [70]	validation_0-logloss:0.40217
# [71]	validation_0-logloss:0.40217
# [72]	validation_0-logloss:0.40217
# [73]	validation_0-logloss:0.40217
# [74]	validation_0-logloss:0.40217
# [75]	validation_0-logloss:0.40217
# [76]	validation_0-logloss:0.40217
# [77]	validation_0-logloss:0.40217
# [78]	validation_0-logloss:0.40217
# [79]	validation_0-logloss:0.40217
# [80]	validation_0-logloss:0.40217
# [81]	validation_0-logloss:0.40217
# [82]	validation_0-logloss:0.40217
# [83]	validation_0-logloss:0.40217
# [84]	validation_0-logloss:0.40217
# [85]	validation_0-logloss:0.40217
# [86]	validation_0-logloss:0.40217
# [87]	validation_0-logloss:0.40217
# [88]	validation_0-logloss:0.40217
# [89]	validation_0-logloss:0.40217
# [90]	validation_0-logloss:0.40217
# [91]	validation_0-logloss:0.40217
# [92]	validation_0-logloss:0.40217
# [93]	validation_0-logloss:0.40217
# [94]	validation_0-logloss:0.40217
# [95]	validation_0-logloss:0.40217
# [96]	validation_0-logloss:0.40217
# model: xgb1
# train_accuracy: 0.8961
# test_accuracy: 0.8156

# %%
xgb3 =XGBClassifier(
    learning_rate =0.01,
    n_estimators=418,
    early_stopping_rounds=50,
    max_depth=6,
    min_child_weight=0,
    gamma=0.45,
    subsample=1.0,
    colsample_bytree=0.75,
    reg_alpha=1e-5,
    objective= 'binary:logistic',
    nthread=-1,
    scale_pos_weight=1,
    random_state=42
)
xgb3.fit(X_train, y_train, eval_set=[(X_val, y_val)])
acc_train = accuracy_score(xgb3.predict(X_train),y_train)
acc_val = accuracy_score(xgb3.predict(X_val),y_val)
print(f"model: xgb1\ntrain_accuracy: {acc_train:.4f}\ntest_accuracy: {acc_val:.4f}")
# Out:
# [0]	validation_0-logloss:0.67585
# [1]	validation_0-logloss:0.67170
# [2]	validation_0-logloss:0.66740
# [3]	validation_0-logloss:0.66525
# [4]	validation_0-logloss:0.66280
# [5]	validation_0-logloss:0.66089
# [6]	validation_0-logloss:0.65709
# [7]	validation_0-logloss:0.65478
# [8]	validation_0-logloss:0.65247
# [9]	validation_0-logloss:0.65020
# [10]	validation_0-logloss:0.64796
# [11]	validation_0-logloss:0.64489
# [12]	validation_0-logloss:0.64108
# [13]	validation_0-logloss:0.63710
# [14]	validation_0-logloss:0.63499
# [15]	validation_0-logloss:0.63322
# [16]	validation_0-logloss:0.62921
# [17]	validation_0-logloss:0.62641
# [18]	validation_0-logloss:0.62468
# [19]	validation_0-logloss:0.62153
# [20]	validation_0-logloss:0.61845
# [21]	validation_0-logloss:0.61543
# [22]	validation_0-logloss:0.61248
# [23]	validation_0-logloss:0.60914
# [24]	validation_0-logloss:0.60736
# [25]	validation_0-logloss:0.60401
# [26]	validation_0-logloss:0.60087
# [27]	validation_0-logloss:0.59766
# [28]	validation_0-logloss:0.59436
# [29]	validation_0-logloss:0.59107
# [30]	validation_0-logloss:0.58800
# [31]	validation_0-logloss:0.58524
# [32]	validation_0-logloss:0.58366
# [33]	validation_0-logloss:0.58057
# [34]	validation_0-logloss:0.57763
# [35]	validation_0-logloss:0.57488
# [36]	validation_0-logloss:0.57209
# [37]	validation_0-logloss:0.57006
# [38]	validation_0-logloss:0.56799
# [39]	validation_0-logloss:0.56673
# [40]	validation_0-logloss:0.56530
# [41]	validation_0-logloss:0.56337
# [42]	validation_0-logloss:0.56100
# [43]	validation_0-logloss:0.55959
# [44]	validation_0-logloss:0.55716
# [45]	validation_0-logloss:0.55462
# [46]	validation_0-logloss:0.55276
# [47]	validation_0-logloss:0.55049
# [48]	validation_0-logloss:0.54954
# [49]	validation_0-logloss:0.54759
# [50]	validation_0-logloss:0.54667
# [51]	validation_0-logloss:0.54428
# [52]	validation_0-logloss:0.54323
# [53]	validation_0-logloss:0.54235
# [54]	validation_0-logloss:0.54052
# [55]	validation_0-logloss:0.53880
# [56]	validation_0-logloss:0.53795
# [57]	validation_0-logloss:0.53571
# [58]	validation_0-logloss:0.53355
# [59]	validation_0-logloss:0.53142
# [60]	validation_0-logloss:0.52928
# [61]	validation_0-logloss:0.52738
# [62]	validation_0-logloss:0.52551
# [63]	validation_0-logloss:0.52358
# [64]	validation_0-logloss:0.52174
# [65]	validation_0-logloss:0.52005
# [66]	validation_0-logloss:0.51938
# [67]	validation_0-logloss:0.51764
# [68]	validation_0-logloss:0.51617
# [69]	validation_0-logloss:0.51512
# [70]	validation_0-logloss:0.51455
# [71]	validation_0-logloss:0.51380
# [72]	validation_0-logloss:0.51249
# [73]	validation_0-logloss:0.51116
# [74]	validation_0-logloss:0.51043
# [75]	validation_0-logloss:0.50874
# [76]	validation_0-logloss:0.50813
# [77]	validation_0-logloss:0.50741
# [78]	validation_0-logloss:0.50579
# [79]	validation_0-logloss:0.50433
# [80]	validation_0-logloss:0.50376
# [81]	validation_0-logloss:0.50304
# [82]	validation_0-logloss:0.50146
# [83]	validation_0-logloss:0.50009
# [84]	validation_0-logloss:0.49856
# [85]	validation_0-logloss:0.49802
# [86]	validation_0-logloss:0.49668
# [87]	validation_0-logloss:0.49621
# [88]	validation_0-logloss:0.49559
# [89]	validation_0-logloss:0.49428
# [90]	validation_0-logloss:0.49280
# [91]	validation_0-logloss:0.49238
# [92]	validation_0-logloss:0.49114
# [93]	validation_0-logloss:0.49010
# [94]	validation_0-logloss:0.48890
# [95]	validation_0-logloss:0.48846
# [96]	validation_0-logloss:0.48724
# [97]	validation_0-logloss:0.48684
# [98]	validation_0-logloss:0.48557
# [99]	validation_0-logloss:0.48429
# [100]	validation_0-logloss:0.48334
# [101]	validation_0-logloss:0.48212
# [102]	validation_0-logloss:0.48173
# [103]	validation_0-logloss:0.48057
# [104]	validation_0-logloss:0.47943
# [105]	validation_0-logloss:0.47839
# [106]	validation_0-logloss:0.47723
# [107]	validation_0-logloss:0.47636
# [108]	validation_0-logloss:0.47595
# [109]	validation_0-logloss:0.47525
# [110]	validation_0-logloss:0.47442
# [111]	validation_0-logloss:0.47419
# [112]	validation_0-logloss:0.47338
# [113]	validation_0-logloss:0.47255
# [114]	validation_0-logloss:0.47226
# [272]	validation_0-logloss:0.41224
# [273]	validation_0-logloss:0.41192
# [274]	validation_0-logloss:0.41194
# [275]	validation_0-logloss:0.41190
# [276]	validation_0-logloss:0.41184
# [277]	validation_0-logloss:0.41163
# [278]	validation_0-logloss:0.41147
# [279]	validation_0-logloss:0.41132
# [280]	validation_0-logloss:0.41138
# [281]	validation_0-logloss:0.41127
# [282]	validation_0-logloss:0.41111
# [283]	validation_0-logloss:0.41114
# [284]	validation_0-logloss:0.41101
# [285]	validation_0-logloss:0.41088
# [286]	validation_0-logloss:0.41081
# [287]	validation_0-logloss:0.41074
# [288]	validation_0-logloss:0.41064
# [289]	validation_0-logloss:0.41055
# [290]	validation_0-logloss:0.41047
# [291]	validation_0-logloss:0.41041
# [292]	validation_0-logloss:0.41042
# [293]	validation_0-logloss:0.41034
# [294]	validation_0-logloss:0.41035
# [295]	validation_0-logloss:0.41020
# [296]	validation_0-logloss:0.41023
# [297]	validation_0-logloss:0.41014
# [298]	validation_0-logloss:0.41013
# [299]	validation_0-logloss:0.40989
# [300]	validation_0-logloss:0.40982
# [301]	validation_0-logloss:0.40974
# [302]	validation_0-logloss:0.40957
# [303]	validation_0-logloss:0.40949
# [304]	validation_0-logloss:0.40944
# [305]	validation_0-logloss:0.40934
# [306]	validation_0-logloss:0.40923
# [307]	validation_0-logloss:0.40919
# [308]	validation_0-logloss:0.40923
# [309]	validation_0-logloss:0.40906
# [310]	validation_0-logloss:0.40899
# [311]	validation_0-logloss:0.40897
# [312]	validation_0-logloss:0.40909
# [313]	validation_0-logloss:0.40910
# [314]	validation_0-logloss:0.40886
# [315]	validation_0-logloss:0.40891
# [316]	validation_0-logloss:0.40890
# [317]	validation_0-logloss:0.40883
# [318]	validation_0-logloss:0.40888
# [319]	validation_0-logloss:0.40888
# [320]	validation_0-logloss:0.40878
# [321]	validation_0-logloss:0.40872
# [322]	validation_0-logloss:0.40870
# [323]	validation_0-logloss:0.40884
# [324]	validation_0-logloss:0.40880
# [325]	validation_0-logloss:0.40878
# [326]	validation_0-logloss:0.40852
# [327]	validation_0-logloss:0.40854
# [328]	validation_0-logloss:0.40850
# [329]	validation_0-logloss:0.40848
# [330]	validation_0-logloss:0.40848
# [331]	validation_0-logloss:0.40846
# [332]	validation_0-logloss:0.40846
# [333]	validation_0-logloss:0.40821
# [334]	validation_0-logloss:0.40822
# [335]	validation_0-logloss:0.40815
# [336]	validation_0-logloss:0.40809
# [337]	validation_0-logloss:0.40785
# [338]	validation_0-logloss:0.40779
# [339]	validation_0-logloss:0.40778
# [340]	validation_0-logloss:0.40783
# [341]	validation_0-logloss:0.40778
# [342]	validation_0-logloss:0.40784
# [343]	validation_0-logloss:0.40790
# [344]	validation_0-logloss:0.40787
# [345]	validation_0-logloss:0.40772
# [346]	validation_0-logloss:0.40765
# [347]	validation_0-logloss:0.40772
# [348]	validation_0-logloss:0.40768
# [349]	validation_0-logloss:0.40767
# [350]	validation_0-logloss:0.40758
# [351]	validation_0-logloss:0.40756
# [352]	validation_0-logloss:0.40749
# [353]	validation_0-logloss:0.40746
# [354]	validation_0-logloss:0.40743
# [355]	validation_0-logloss:0.40736
# [356]	validation_0-logloss:0.40730
# [357]	validation_0-logloss:0.40720
# [358]	validation_0-logloss:0.40722
# [359]	validation_0-logloss:0.40714
# [360]	validation_0-logloss:0.40717
# [361]	validation_0-logloss:0.40720
# [362]	validation_0-logloss:0.40703
# [363]	validation_0-logloss:0.40703
# [364]	validation_0-logloss:0.40714
# [365]	validation_0-logloss:0.40709
# [366]	validation_0-logloss:0.40714
# [367]	validation_0-logloss:0.40709
# [368]	validation_0-logloss:0.40704
# [369]	validation_0-logloss:0.40715
# [370]	validation_0-logloss:0.40707
# [371]	validation_0-logloss:0.40711
# [372]	validation_0-logloss:0.40697
# [373]	validation_0-logloss:0.40691
# [374]	validation_0-logloss:0.40687
# [375]	validation_0-logloss:0.40689
# [376]	validation_0-logloss:0.40675
# [377]	validation_0-logloss:0.40676
# [378]	validation_0-logloss:0.40679
# [379]	validation_0-logloss:0.40677
# [380]	validation_0-logloss:0.40676
# [381]	validation_0-logloss:0.40684
# [382]	validation_0-logloss:0.40678
# [383]	validation_0-logloss:0.40677
# [384]	validation_0-logloss:0.40661
# [385]	validation_0-logloss:0.40662
# [386]	validation_0-logloss:0.40652
# [387]	validation_0-logloss:0.40647
# [388]	validation_0-logloss:0.40644
# [389]	validation_0-logloss:0.40639
# [390]	validation_0-logloss:0.40643
# [391]	validation_0-logloss:0.40632
# [392]	validation_0-logloss:0.40619
# [393]	validation_0-logloss:0.40616
# [394]	validation_0-logloss:0.40612
# [395]	validation_0-logloss:0.40605
# [396]	validation_0-logloss:0.40608
# [397]	validation_0-logloss:0.40605
# [398]	validation_0-logloss:0.40600
# [399]	validation_0-logloss:0.40601
# [400]	validation_0-logloss:0.40596
# [401]	validation_0-logloss:0.40602
# [402]	validation_0-logloss:0.40604
# [403]	validation_0-logloss:0.40589
# [404]	validation_0-logloss:0.40588
# [405]	validation_0-logloss:0.40595
# [406]	validation_0-logloss:0.40600
# [407]	validation_0-logloss:0.40599
# [408]	validation_0-logloss:0.40598
# [409]	validation_0-logloss:0.40604
# [410]	validation_0-logloss:0.40610
# [411]	validation_0-logloss:0.40595
# [412]	validation_0-logloss:0.40597
# [413]	validation_0-logloss:0.40589
# [414]	validation_0-logloss:0.40591
# [415]	validation_0-logloss:0.40591
# [416]	validation_0-logloss:0.40593
# [417]	validation_0-logloss:0.40596
# model: xgb1
# train_accuracy: 0.9003
# test_accuracy: 0.8045

# %% [markdown]
# # Make prediction

# %%
best=xgb3
predictions = best.predict(test_df)
submission_data["Survived"] = predictions
#submission_data["Survived"] = submission_data["Survived"].map({0: "False", 1: "True"})
submission_data.head(10)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1
# 5          897         0
# 6          898         1
# 7          899         0
# 8          900         1
# 9          901         0

# %%
submission_data.to_csv('submission.csv', index=False)
